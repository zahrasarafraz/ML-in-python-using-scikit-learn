# %%
import pandas as pd 
data = pd.read_csv('Advertising.csv',index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
data.shape
# Out:
# (200, 4)

# %%
##visualize between data and output
import seaborn as sns
sns.pairplot(data,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',size=10, kind='reg')
# Out:
# C:\Users\Hossein\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
X=data[['TV', 'Radio', 'Newspaper']]
X.head()
# Out:
#       TV  Radio  Newspaper
# 1  230.1   37.8       69.2
# 2   44.5   39.3       45.1
# 3   17.2   45.9       69.3
# 4  151.5   41.3       58.5
# 5  180.8   10.8       58.4

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y=data['Sales']

# %%
y.head()
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (50,)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict=linreg.predict(X_test)

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_predict)
# Out:
# 1.0668917082595213
